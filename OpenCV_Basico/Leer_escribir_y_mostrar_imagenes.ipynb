# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import numpy as np 
print("Todo correctamente importado")
# Out:
# Todo correctamente importado

# %%
# Leemos una imagen utilizando cv2.imread y añadiendo la ruta de la misma
# Y la almacenamos en la variable 'input'
input = cv2.imread('caballos.jpg')


# Para Agregar un titulo a la imagen utilizamos 'plt.title'
# Para MOSTRAR la imagen utilizamos 'plt.imshow'
plt.title('Hello World')
plt.imshow(input)

# %%
# Pero los colores resultantes claramente no son los correctos. Esto se debe a que OpenCV reprensenta los colores en formato BGR
# Por lo que para mostrar la imagen correctamente debemos convertirla a RGB
# Para ello utilizamos la funcion cv2.cvtColor
# La funcion cv2.cvtColor recibe como parametros la imagen y el color que queremos convertir
# En este caso utilizamos la funcion cv2.cvtColor(input, cv2.COLOR_BGR2RGB)

plt.imshow(cv2.cvtColor(input, cv2.COLOR_BGR2RGB))

# %%
# Utilizamos input.shape para obtener el tamaño de la imagen. El primer valor que se imprimira es el alto de la imagen,
# el segundo el ancho y el tercero el numero de canales de la imagen
print (input.shape)
# Out:
# (3910, 5866, 3)

# %%
# Si queremos obtener cada uno de estos datos por separado podemos hacer lo siguiente:
print ('Altura de la imagen:', int(input.shape[0]), 'pixels')
print ('Ancho de la imagen:', int(input.shape[1]), 'pixels')
print ('Numero de canales de la imagen:', int(input.shape[2]), 'canales')
# Out:
# Altura de la imagen: 3910 pixels
# Ancho de la imagen: 5866 pixels
# Numero de canales de la imagen: 3 canales

# %% [markdown]
# ¿Como guardamos una imagen?

# %%
# Utilizamos 'imwrite' para guardar la imagen
cv2.imwrite('output.jpg', input)
cv2.imwrite('output.png', input)
# Out:
# True
